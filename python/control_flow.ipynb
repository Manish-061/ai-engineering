# %% [markdown]
# ### Control flow allows Python program to - make decisions, repeat tasks, and jump executions. Without control flow program executes from top to bottom.

# %%
# Conditionals : decision making
# if, elif, else

if 5 > 6:
    print("Hello")
elif 5 < 8:
    print("Hi")
else:
    print("Bye")

# else : fallback
# Out:
# Hi

# %%
# Truthiness: Object is considered Truthy if it evaluates to 'true' and 'falsy' if it evaluates to 'false'

# Truthy values: non-zero numbers, non-empty string, non-empty list,tuple,dict, set
# Falsy values: None, False, Empty sequence, collections

# %%
# Loop: Loop is used to perform a task repeatedly until a particular condition is satisfied. 
# Python mainly provides: 
        # for loop     # while loop

# for: iterates over iterable

for i in range(5):
    print(i) 

for j in range(2, 6):
    print(j, end="")

for k in range(10, 0, -1):
    print(k, end=" ")
# Out:
# 0
# 1
# 2
# 3
# 4
# 234510 9 8 7 6 5 4 3 2 1

# %%
# while loop: runs while condition is true.
i = 0
while i < 5:
    print("Manish", end=" ")
    i += 1
# Out:
# Manish Manish Manish Manish Manish

# %%
# controlling execution
# break: terminate loop immediately
for i in range(5):
    if i == 5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# continue: skip iteration
for i in range(3):
    if i == 0:
        continue
    print(i)
# Out:
# 1
# 2

# %%
# pass: placeholder statement (mostly used in development)
for i in range(5):
    pass

# %%
## Control Flow in Python

### Overview
Control flow allows Python programs to make decisions, repeat tasks, and jump executions. Without control flow, programs execute from top to bottom.

### Topics Covered
- **Conditionals**: if, elif, else statements for decision making
- **Truthiness**: Truthy and falsy values in Python
- **Loops**: for and while loops for repetitive tasks
- **Loop Control**: break, continue, and pass statements
